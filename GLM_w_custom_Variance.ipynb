# %% [markdown]
# # Deviating away from OLS for predictive distributions
#
# In a standard Ordinary Least Squares (OLS) regression, we assume homoscedasticity of the residuals. In case the residuals are normally distributed, an OLS fit is equivalent to modelling the data as
#
# $$Y|X \sim N(\beta X, \sigma^2)$$
#
# Ie, conditioned on $X$, the response variable $Y$ is normally distributed with mean $\beta X$ and constanst variance $\sigma^2$. The parameters $\beta$ and $\sigma$ can be found using Maximum Likelihood Estimation (MLE), which in this particular case is equivalent to minimizing the sum of squared residuals.
#
# There are several ways to deviate from this paradigm, two examples
#
# 1. $Y|X$ could follow a different distribution, eg a gamma distribution if we're dealing with a positive response variable $Y$. For cases where the distribution is part of the exponential family we can leverage a [Generalized Linear Model (GLM)](https://en.wikipedia.org/wiki/Generalized_linear_model)
#
# 2. The residuals are heteroskedastic, for instance the variance of the residuals can be a function of X, $\sigma^2(X) = f(X)$. For example if the variance grows exponentionally as $X$ increases we can try to fit the following model
#
# $$Y|X \sim N(a+b*X, \exp(c+d*X))$$
#
# We will demonstrate this particular example in this notebook, and conclude with how this can be generalized.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

import statsmodels.api as sm

rng = np.random.default_rng()

# %%
n_samples = 1000

x = rng.uniform(-1.0, 1, size = n_samples)

# %% [markdown]
# #### Standard OLS case - normally distributed errors with constanst variance

# %%
a0 = 0.8
b0 = 1.2

y0 = rng.normal(a0 + b0 * x, 1.0, size = n_samples)

plt.scatter(x,y0);

# %% [markdown]
# OLS fit

# %%
X = sm.add_constant(x)
model = sm.OLS(y0,X)
results = model.fit()
results.params
# Out:
# array([0.84317175, 1.01965639])

# %% [markdown]
# ### Repeating the same excercise but formulated as a MLE problem

# %%
def log_pdf(x,mu,sigma):
    return -0.5 * np.log(2.0*np.pi*sigma**2) - (x-mu)**2/(2.0*sigma**2)

# %%
def neg_log_ll_OLS(theta):
    a, b, sigma = theta
    return -1.0 * np.sum(log_pdf(y0,a+b*x,sigma))

# %%
a0_est, b0_est, sigma0_est = sp.optimize.fmin(neg_log_ll_OLS, (0.0, 0.0, 0.01))
a0_est, b0_est, sigma0_est
# Out:
# Optimization terminated successfully.
#          Current function value: 1382.391394
#          Iterations: 197
#          Function evaluations: 358
# (0.8431570499144667, 1.0196302655919751, 0.9641063317127301)

# %% [markdown]
# We find the same parameters a, b as before as it should.

# %% [markdown]
# ## Heteroscedastic Errors
#
# Now lets assume we want to model the heteroscedasiticy as $\sigma^2(X) = \exp(c+d*X)$ with unknow parameters $c$, $d$
#
# $$Y|X \sim N(a + b * X, \exp(c + d * X))$$

# %%
a1 = 0.8
b1 = 1.2

c1 = 0.1
d1 = 0.9

y = rng.normal(a0 + b0 * x, np.exp(c1 + d1 * x), size = n_samples)

plt.scatter(x,y)

# %% [markdown]
# ### MLE fit
#
# The MLE problem is similar as before, but for generalized sigma

# %%
def neg_log_ll_generalized(theta):
    a_mu, b_mu, a_sigma, b_sigma = theta
    mu = a_mu + b_mu * x
    sigma = np.exp(a_sigma + b_sigma * x) #take exp to ensure sigma is positve
    return -1.0 * np.sum(log_pdf(y,mu,sigma))

# %%
a1_est, b1_est, c1_est, d1_est = sp.optimize.fmin(neg_log_ll_generalized, (0.0, 0.0, 0.0, 0.0))
a1_est, b1_est, c1_est, d1_est
# Out:
# Optimization terminated successfully.
#          Current function value: 1494.907899
#          Iterations: 305
#          Function evaluations: 508
# (0.7780558426602124,
#  1.1751511493349582,
#  0.06919610432045656,
#  0.8733636994836593)

# %%
a1, b1, c1, d1
# Out:
# (0.8, 1.2, 0.1, 0.9)

# %% [markdown]
# The fitted parameters are close to the actual parameters

# %% [markdown]
# ### Predictive distribution
#
# Now we have the MLE estimates, we can construct a predictive distribution for $Y$ given $X$

# %%
def pdf2(y,x,a,b,c,d):
    mu = a + b * x
    sigma = np.exp(c + d * x)

    return np.exp(-(y-mu)**2/(2.0*sigma**2))/np.sqrt(2.0*np.pi * sigma**2)

# %%
y_vals = np.linspace(-8,8,100)

for x in [-0.75, -0.25, 0.25, 0.75]:
    plt.plot(y_vals, pdf2(y_vals, x, a1_est, b1_est, c1_est, d1_est), label = F'x = {x}')
plt.legend()

# %% [markdown]
# ### General case
#
# The general case, we want to model the response variable $Y$ as
# $$Y|X \sim \phi(f(X), g(X))$$
# with $\phi(y;\theta)$ the probability density function and where mean and variance functions $f(X)$ and $g(X)$ can be represented as neural networks. We can find the neural network parameters by miniziming the negative log likelihood
#
# $$\sum_i - \log(\phi(y_i; f(X_i), g(X_i)))$$
#
#
#
# Solving this general problem, sp.optimize.fmin no longer suffices and hence should be formulated as a back-propagation problem.
